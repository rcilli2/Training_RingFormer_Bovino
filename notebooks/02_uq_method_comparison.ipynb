# %% [markdown]
# # Comparing uncertainty-quantification methods
#
# This notebook compares MC Dropout, Deep Ensemble, Training Subsample Ensemble, LLLA, and TabICLv2 from their saved leave-one-campaign-out predictions. No model is trained here.

# %%
from pathlib import Path
import sys
import matplotlib.pyplot as plt

ROOT = Path.cwd().resolve()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / 'src'))
import bovino_results as br

# %% [markdown]
# ## Confidence calibration and error detection

# %%
fig, axes = br.plot_loco_reliability_and_roc()
plt.show()

# %% [markdown]
# ## Reading the comparison
#
# The reliability diagram evaluates calibration, whereas the ROC curves evaluate how well confidence ranks incorrect predictions. A method can perform well on one question and poorly on the other. Compare methods under the same split and score; do not interpret the numerical magnitude of MI as directly comparable across unrelated posterior approximations.
