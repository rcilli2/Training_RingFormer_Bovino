# %% [markdown]
# # BOVINO saved-results explorer
#
# This notebook reproduces the central validation figures without importing PyTorch or training a model. The packaged runs use MiniLM PCA16 + XYZ/depth.

# %%
from pathlib import Path
import sys
import matplotlib.pyplot as plt

ROOT = Path.cwd().resolve()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / 'src'))
import bovino_results as br

# %% [markdown]
# ## LOBO versus leave-one-campaign-out

# %%
fig, axes = br.plot_protocol_confusions()
plt.show()

# %% [markdown]
# ## Calibration and confidence-based error detection under unseen campaigns

# %%
fig, axes = br.plot_loco_reliability_and_roc()
plt.show()

# %% [markdown]
# ## Interpretation
#
# - LOCO measures generalization to an unseen campaign rather than a nearby held-out borehole.
# - Saved predictions permit metric and figure auditing, but not retraining.
# - Continue with notebooks 01 and 02 for the UQ benchmark and distribution-shift stress tests.
